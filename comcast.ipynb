# %%
# Comcast is an American global telecommunication company. The firm has been providing terrible customer service. They continue to fall short despite repeated promises to improve. 
# Only last month (October 2016) the authority fined them a $2.3 million, after receiving over 1000 consumer complaints.

# %%
# Data Dictionary

•	Ticket #: Ticket number assigned to each complaint
•	Customer Complaint: Description of complaint
•	Date: Date of complaint
•	Time: Time of complaint
•	Received Via: Mode of communication of the complaint
•	City: Customer city
•	State: Customer state
•	Zip code: Customer zip
•	Status: Status of complaint
•	Filing on behalf of someone
# Out:
#   File "<ipython-input-4-a9d28d3179e9>", line 3
#     •	Ticket #: Ticket number assigned to each complaint
#     ^
# SyntaxError: invalid character in identifier

# %%
# To perform these tasks, I can use any of the different Python libraries such as NumPy, SciPy, Pandas, scikit-learn, matplotlib, and BeautifulSoup.

# %%
# To Do:

# 1 Import data into Python environment.
# 2 Provide the trend chart for the number of complaints at monthly and daily granularity levels.
# 3 Provide a table with the frequency of complaint types.
# 4 Which complaint types are maximum i.e., around internet, network issues, or across any other domains.
# 5 Create a new categorical variable with value as Open and Closed. Open & Pending is to be categorized as Open and Closed & Solved is to be categorized as Closed.
# 6 Provide state wise status of complaints in a stacked bar chart. Use the categorized variable from Q3. Provide insights on: Which state has the maximum complaints. Which state has the highest percentage of unresolved complaints
# 7 Provide the percentage of complaints resolved till date, which were received through the Internet and customer care calls.

# The analysis results to be provided with insights wherever applicable.

# %%
# 0 import Libraries

import numpy as np
import pandas as pd

# %%
# 1 Import data into Python environment.

comcast_data = pd.read_csv("comcast_complaints_data.csv")

# %%
comcast_data.head()
# Out:
#   Ticket #                                 Customer Complaint  Month  Day  \
# 0   250635                      Comcast Cable Internet Speeds      4   22
# 1   223441       Payment disappear - service got disconnected      8    4
# 2   242732                                  Speed and Service      4   18
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...      7    5
# 4   307175         Comcast not working and no service to boot      5   26
#
#    Year         Time        Received Via      City     State  Zip code  \
# 0  2015   3:53:50 PM  Customer Care Call  Abingdon  Maryland     21009
# 1  2015  10:22:56 AM            Internet   Acworth   Georgia     30102
# 2  2015   9:55:47 AM            Internet   Acworth   Georgia     30101
# 3  2015  11:59:35 AM            Internet   Acworth   Georgia     30101
# 4  2015   1:25:26 PM            Internet   Acworth   Georgia     30101
#
#    Status Filing on Behalf of Someone
# 0  Closed                          No
# ...

# %%
comcast_data.tail()
# Out:
#      Ticket #                          Customer Complaint  Month  Day  Year  \
# 2219   213550                        Service Availability      2    4  2015
# 2220   318775  Comcast Monthly Billing for Returned Modem      2    6  2015
# 2221   331188                     complaint about comcast      9    6  2015
# 2222   360489      Extremely unsatisfied Comcast customer      6   23  2015
# 2223   363614        Comcast, Ypsilanti MI Internet Speed      6   24  2015
#
#              Time        Received Via        City     State  Zip code  Status  \
# 2219   9:13:18 AM  Customer Care Call  Youngstown   Florida     32466  Closed
# 2220   1:24:39 PM  Customer Care Call   Ypsilanti  Michigan     48197  Solved
# 2221   5:28:41 PM            Internet   Ypsilanti  Michigan     48197  Solved
# 2222  11:13:30 PM  Customer Care Call   Ypsilanti  Michigan     48197  Solved
# 2223  10:28:33 PM  Customer Care Call   Ypsilanti  Michigan     48198    Open
#
#      Filing on Behalf of Someone
# ...

# %%
# import matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# first five in Month

comcast_data = pd.read_csv("comcast_complaints_data.csv")
comcast_data_month = comcast_data['Month']
comcast_data_month.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: Month, dtype: int64

# %%
# first five in Day

comcast_data_day = comcast_data['Day']
comcast_data_day.head()
# Out:
# 0    27
# 1    27
# 2    21
# 3    22
# 4    29
# Name: Day, dtype: int64

# %%
# counting how many per Month

comcast_data_month.value_counts()
# Out:
# 6     1046
# 4      375
# 5      317
# 8       67
# 12      65
# 2       59
# 1       55
# 9       55
# 10      53
# 7       49
# 3       45
# 11      38
# Name: Month, dtype: int64

# %%
# counting how many per Day

comcast_data_day.value_counts()
# Out:
# 6     272
# 24    249
# 23    225
# 4     206
# 5     131
# 25    126
# 26     90
# 29     87
# 30     86
# 27     81
# 28     79
# 18     69
# 13     68
# 22     66
# 16     65
# 17     60
# 15     58
# 14     54
# 20     51
# 19     50
# 21     41
# 31     10
# Name: Day, dtype: int64

# %%
# 2 Provide the trend chart for the number of complaints at monthly and daily granularity levels.

# Monthly grandularity
month_dict = {}
day_dict = {}
month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jly", "Aug", "Sep", "Oct", "Nov", "Dec"]
#day_name = ["Sun", "Mon", "Tues", "Wed", "Thurs", "Fri", "Sat"]
for x in range(1,13):
    month_dict[x] = 0

for x in comcast_data_month:
    month_dict[x] += 1

for x in range(1,32):
    day_dict[x] = 0

for x in comcast_data_day:
    day_dict[x] += 1
plt.subplot(211)
plt.bar(month_names, list(month_dict.values()))
plt.subplot(212)
plt.bar(range(len(day_dict)), list(day_dict.values()))
plt.show()

# this looks pretty useless - how can I make it better?

# %%
# Day

plt.plot(comcast_data_day)
plt.show()

# %%
# See if/how I can combine two columns - also pretty useless with that much data

plt.plot(comcast_data['Month'],comcast_data['State'])
plt.show()

# %%
# As above, but with Month & Day

plt.plot(comcast_data['Month'], comcast_data['Day'])
plt.title("When are these complaints happening?")
plt.xlabel("Month")
plt.ylabel("Day")
plt.show()

# Looks somewhat okay

# %%
plt.plot(comcast_data.Month,comcast_data.Day)
plt.show()

# %%
# 3 Provide a table with the frequency of complaint types.

comcast_data_frequency = comcast_data['Customer Complaint']

comcast_data_frequency.value_counts()
# Out:
# Comcast                                                                                  83
# Comcast Internet                                                                         18
# Comcast Data Cap                                                                         17
# comcast                                                                                  13
# Comcast Billing                                                                          11
#                                                                                          ..
# Comcast Internet down since 4/25 with no resolve                                          1
# Misleading Advertising                                                                    1
# Unfair Charges                                                                            1
# No internet available since a comcast techinitian did an intervention to change plans     1
# ...

# %%
# 4 Which complaint types are maximum i.e., around internet, network issues, or across any other domains.

# %%
comcast_data_frequency.max()
# Out:
# 'xfinity customer service'

# %%
comcast_data_frequency.min()
# Out:
# '(Comcast is not my complaint!) Cyber Tele-marketing is my complaint!'

# %%
# 5 Create a new categorical variable with value as Open and Closed. Open & Pending is to be categorized as Open and Closed & Solved is to be categorized as Closed.

# %%
comcast_data_status = comcast_data['Status']
comcast_data_status.head()
# Out:
# 0    Closed
# 1    Closed
# 2    Closed
# 3      Open
# 4    Solved
# Name: Status, dtype: object

# %%
comcast_data_status.value_counts()
# Out:
# Solved     973
# Closed     734
# Open       363
# Pending    154
# Name: Status, dtype: int64

# %%
# 6 Provide state wise status of complaints in a stacked bar chart. Use the categorized variable from Q3. Provide insights on: Which state has the maximum complaints. Which state has the highest percentage of unresolved complaints

# %%
comcast_data_frequency = comcast_data['Customer Complaint']
comcast_data_state = comcast_data['State']
comcast_data_frequency.value_counts(['State'])
# Out:
# Comcast                                                                                  0.037320
# Comcast Internet                                                                         0.008094
# Comcast Data Cap                                                                         0.007644
# comcast                                                                                  0.005845
# Comcast Billing                                                                          0.004946
#                                                                                            ...
# Comcast Internet down since 4/25 with no resolve                                         0.000450
# Misleading Advertising                                                                   0.000450
# Unfair Charges                                                                           0.000450
# No internet available since a comcast techinitian did an intervention to change plans    0.000450
# ...

# %%
# 7 Provide the percentage of complaints resolved till date, which were received through the Internet and customer care calls.

# %%
comcast_data_status.value_counts(["Solved"])
# Out:
# Solved     0.437500
# Closed     0.330036
# Open       0.163219
# Pending    0.069245
# Name: Status, dtype: float64

# %%
comcast_data_how_did_you_find_us = comcast_data["Received Via"]

# %%
comcast_data_how_did_you_find_us.value_counts(["Internet"])
# Out:
# Customer Care Call    0.503147
# Internet              0.496853
# Name: Received Via, dtype: float64

# %%
comcast_data_status.value_counts(["Solved"], ["Internet"])
# Out:
# Solved     0.437500
# Closed     0.330036
# Open       0.163219
# Pending    0.069245
# Name: Status, dtype: float64

# %%
count1 = comcast_data_status.count()
count1
# Out:
# 2224
